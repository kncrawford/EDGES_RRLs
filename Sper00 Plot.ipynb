# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
y = open('sper00_col.csv')
reader = csv.reader(y,  delimiter=' ')

spec=np.zeros(376, 8193) #loads data into array for processing

index1=0
index2=0

for row in reader:
    spec[index1, index2]=row[1]
    index2+=1
    if row[3] != 
spec=np.array(spec)
#print(data)

# %%
day1 = list(filter(lambda x: x[2]=="1" and x[3]=="2016:029", data))

freq = list(map(lambda x: x[0], day1))
spec = list(map(lambda x: x[1], day1))

print(day1)
# Out:
# [array(['50.000000', '12461.283981', '1', '2016:029'],
#       dtype='<U16'), array(['50.006104', '12450.153077', '1', '2016:029'],
#       dtype='<U16'), array(['50.012207', '12449.418123', '1', '2016:029'],
#       dtype='<U16'), array(['50.018311', '12456.010412', '1', '2016:029'],
#       dtype='<U16'), array(['50.024414', '12461.880805', '1', '2016:029'],
#       dtype='<U16'), array(['50.030518', '12451.262664', '1', '2016:029'],
#       dtype='<U16'), array(['50.036621', '12439.309664', '1', '2016:029'],
#       dtype='<U16'), array(['50.042725', '12433.292167', '1', '2016:029'],
#       dtype='<U16'), array(['50.048828', '12429.996519', '1', '2016:029'],
#       dtype='<U16'), array(['50.054932', '12431.889012', '1', '2016:029'],
#       dtype='<U16'), array(['50.061035', '12429.964365', '1', '2016:029'],
#       dtype='<U16'), array(['50.067139', '12429.568701', '1', '2016:029'],
#       dtype='<U16'), array(['50.073242', '12433.909310', '1', '2016:029'],
# ...

# %%
plt.plot(freq, spec, label='2016:029')

#plt.title("", fontsize='16')
plt.legend()
plt.xlabel("Frequency (MHz)")
plt.ylabel("Spectrum Temperature (K)")
plt.show(block=False)
